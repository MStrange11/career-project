# %%
# !pip install ollama

# %%
import ollama

# %%
def embed_(text:str):
    return ollama.embeddings(model="nomic-embed-text",prompt=text)

# %%
list(embed)
# Out:
# [('embedding',
#   [0.5898658037185669,
#    0.4017767012119293,
#    -3.305577278137207,
#    -0.5252460241317749,
#    0.7499712705612183,
#    1.5196346044540405,
#    -0.125183567404747,
#    0.3967916965484619,
#    0.06763441860675812,
#    -1.1086547374725342,
#    0.6925441026687622,
#    1.2788687944412231,
#    1.145966649055481,
#    1.0880662202835083,
#    0.2517137825489044,
#    0.2930832505226135,
#    0.1520555466413498,
#    -0.6342281103134155,
#    -0.2098449319601059,
#    -0.1958695501089096,
#    -1.795493245124817,
#    -0.629237711429596,
#    0.03796372935175896,
#    -0.6677831411361694,
#    1.2611770629882812,
#    1.2769991159439087,
#    -0.15981332957744598,
#    -0.0019203114788979292,
#    -0.2978396415710449,
#    -0.4800446629524231,
#    1.2057751417160034,
#    -0.6379294991493225,
#    -0.5399431586265564,
#    -1.0354969501495361,
#    0.6310412287712097,
#    -1.2089250087738037,
#    0.6834036111831665,
#    -0.05848854035139084,
# ...

# %%
len(list(embed)[0][1])
# Out:
# 768

# %%
def text_(text:str):
    return ollama.generate(model="gemma3:270m",prompt=text)

# %%
print(response)
# Out:
# model='gemma3:270m' created_at='2025-09-03T07:15:26.9343471Z' done=True done_reason='stop' total_duration=1924379000 load_duration=1171214700 prompt_eval_count=16 prompt_eval_duration=137180200 eval_count=33 eval_duration=614658100 response='Rayleigh scattering is a phenomenon where the wavelength of a light diffracted by a particle due to the interaction of the particle with the wavelength of the light.\n' thinking=None context=[105, 2364, 107, 155122, 121707, 19389, 528, 886, 13315, 236761, 106, 107, 105, 4368, 107, 30958, 53700, 19389, 563, 496, 20284, 1298, 506, 19897, 529, 496, 2214, 2675, 26174, 684, 496, 13366, 2779, 531, 506, 9553, 529, 506, 13366, 607, 506, 19897, 529, 506, 2214, 236761, 107]

# %%
response.response
# Out:
# 'Rayleigh scattering is a phenomenon where the wavelength of a light diffracted by a particle due to the interaction of the particle with the wavelength of the light.\n'
